# %%
import torch

# %%
! pip list
# Out:
# Package                                  Version
# ---------------------------------------- -------------------
# a2a-sdk                                  0.3.26
# absl-py                                  1.4.0
# accelerate                               1.13.0
# access                                   1.1.10.post3
# affine                                   2.4.0
# aiofiles                                 22.1.0
# aiohappyeyeballs                         2.6.1
# aiohttp                                  3.13.5
# aiosignal                                1.4.0
# aiosqlite                                0.22.1
# alabaster                                1.0.0
# albucore                                 0.0.24
# albumentations                           2.0.8
# ale-py                                   0.11.2
# alembic                                  1.18.4
# altair                                   5.5.0
# annotated-doc                            0.0.4
# ...
